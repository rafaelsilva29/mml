# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
run TP1920.py

# %%
# Converter e definir as imagens
#resizeImageAndConvert()

# %%
# Ler das imagens para uma matriz 'X' e um array 'lista'
X, lista, size = readImages()
size
# Out:
# 48

# %%
X[1].shape
# Out:
# (65025,)

# %%
X.shape
# Out:
# (48, 65025)

# %%
# Obter os vectores pp de acordo com um certo nivel de confianca
k, eigenvalues, eigenvectors, phi, mean, variance = pca(X, 0.9)
eigenvalues
# Out:
# Número de vectores pp a usar: 13
# array([1.00869099e+09, 6.19188595e+08, 4.35779250e+08, 3.44530890e+08,
#        2.26068203e+08, 1.31465245e+08, 1.09521515e+08, 8.11303696e+07,
#        6.76638661e+07, 5.63355374e+07, 5.18214455e+07, 5.11439369e+07,
#        4.72851992e+07, 4.12271639e+07, 3.75110815e+07, 3.21917090e+07,
#        3.17179961e+07, 2.83533316e+07, 2.69554564e+07, 2.57687866e+07,
#        2.30993236e+07, 2.09821907e+07, 1.96553591e+07, 1.91886680e+07,
#        1.82429692e+07, 1.68259475e+07, 1.58000295e+07, 1.50220309e+07,
#        1.40354211e+07, 1.35912543e+07, 1.23987780e+07, 1.16291114e+07,
#        1.11702623e+07, 1.03194000e+07, 9.50276006e+06, 8.87648265e+06,
#        8.70859376e+06, 8.60815525e+06, 8.24206338e+06, 7.73722020e+06,
#        7.61733886e+06, 6.94365092e+06, 6.78659052e+06, 5.14986980e+06,
#        4.87394844e+06, 4.05670949e+06, 3.90457562e+06, 1.20451912e-22])

# %%
# Obter os vectores pp de acordo com um certo nivel de confianca
k, eigenvalues, eigenvectors, phi, mean, variance = pca(X, 0.9)
# Alterar nome da variável
ponto=eigenvalues
# Obter o gráfico do cotovelo
plt.figure(figsize=(10,10))
t = np.arange(0, size, 1)
plt.plot(t, eigenvalues, 'x')
#plt.plot(np.argmin(ponto), eigenvalues[np.argmin(ponto)], 'o')
plt.plot(k, eigenvalues[k], 'o')
plt.show()
# Out:
# Número de vectores pp a usar: 13

# %%
eigenvectors.T[0]
# Out:
# array([-0.00064952, -0.00067356, -0.00066299, ..., -0.00041102,
#        -0.00040529, -0.00027831])

# %%
# Exemplo de uma eigenface do dataset
display(plt.matshow(np.reshape(eigenvectors.T[0], (255,255)), cmap=plt.cm.RdYlGn))

# %%
# Exemplo da "cara média" do dataset
display(plt.matshow(np.reshape(mean, (255,255)), cmap='gray'))

# %%
# Obter os coeficientes das projeccoes das eigenfaces
coef_proj = coefProj(phi, eigenvectors, X.shape[0])
coef_proj
# Out:
# [array([-5063.64161349,   482.82292275,  5867.89817726, -2012.31563211,
#          -990.71852359,  2093.59263324,  -110.36709565,   609.41822036,
#          -592.87510871,  3539.6992611 , -1501.4016827 ,   378.2186335 ,
#          -894.37765443]),
#  array([ 6023.28112691,   749.64226173,  1660.50609709,   762.64246191,
#         -2201.26886661,   663.06371829,   -88.89963777, -1033.69448058,
#           607.49879209,    35.12564333,   605.81083962,  1106.58393413,
#          1931.98899727]),
#  array([-2684.60360399,  -924.82719909,  1150.09947706, -3363.8145327 ,
#           262.97440744, -2884.76165632, -2539.20006291, -1012.39281427,
#           572.1921882 , -1572.16617963, -1940.49192177, -1099.8847965 ,
#          -584.49242135,  -422.16329739,   272.27245363,   307.11303989,
#             4.32527398]),
#  array([-2625.4623864 ,  -724.10266257,  1004.30449619, -3686.229622  ,
#           195.82159132, -2890.8233697 , -2611.04947318, -1136.57095892,
#          -314.03849426,   -33.12645276,   441.14334717,  -513.0275061 ,
#          -129.01517896]),
#  array([-4941.42421289,   296.71511263,  6545.24876794,  -889.13859605,
#           309.71219935,  2559.81848938,   218.10659409,   690.71810918,
#           280.58535724,   608.5721111 ,  -173.49246594,  1515.34130864,
#          -205.50309156]),
#  array([-5151.80983462,   651.85229811,  5533.12700643,   270.40195167,
#          -641.79427448,   217.49884414,   323.28234117,  1598.62654102,
#          1012.96141106, -1175.24262456,   343.1013129 ,  -939.84059123,
#           -98.34479112]),
#  array([-5177.39672655, -3963.2375152 ,   684.40723326,  5326.95630033,
#            28.90863516,  1574.29937763,   953.17472965, -2585.99362397,
#         -2741.97357708,  -868.61628745,   915.56255674, -1256.75226697,
#           262.34493554]),
#  array([ 5758.46696666,  1616.36018776,   638.22885619,   770.52734905,
#         -4707.44563467, -3120.27256219,  2426.52296532,   590.24916759,
#         -1033.35696224,   151.02300625,  -608.70895403,  -961.39073208,
#          -886.36105883])]

# %%
# Imagem para teste
input_img = Image.open('TestSet/joao_angry.gif').convert('L')
input_img
# Out:
# <PIL.Image.Image image mode=L size=255x255 at 0x1190F9C90>

# %%
# Teste do reconhecimento
dist, test_coef_proj = testar(input_img, mean, eigenvectors, eigenvalues, X.shape[0], coef_proj, 'mahalanobis')
image = 0
if np.size(dist) > 0 : 
    image = lista[np.argmin(dist)]
image
# Out:
# Falhou no reconhecimento.
# 0

# %%
coef_proj = np.reshape(coef_proj, (eigenvectors.shape[1], size))
#distance = np.sum( np.divide((coef_proj[:,4]-test_coef_proj)**2, eigenvalues[:eigenvectors.shape[1]]) )
#distance

# %%
def mahalanobis(x, y, eigenvalues, k):
    if x.shape[0] != y.shape[0]:
        return (-1)
    N = x.shape[1]
    distance=[0]*N
    for i in range(N):
        distance[i] = [np.sum(np.divide((x[:,i]-y)**2, eigenvalues[:k]))]
    return distance

# %%
coef_proj = np.reshape(coef_proj, (eigenvectors.shape[1], size))
dist = mahalanobis(coef_proj, test_coef_proj, eigenvalues, eigenvectors.shape[1])
distanceMahalanobis = np.sum(dist)
distanceMahalanobis
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-bbba9399e099> in <module>
#       1 coef_proj = np.reshape(coef_proj, (eigenvectors.shape[1], size))
# ----> 2 dist = mahalanobis(coef_proj, test_coef_proj, eigenvalues, eigenvectors.shape[1])
#       3 distanceMahalanobis = np.sum(dist)
#       4 distanceMahalanobis
#
# <ipython-input-117-719057742d13> in mahalanobis(x, y, eigenvalues, k)
#       1 def mahalanobis(x, y, eigenvalues, k):
# ----> 2     if x.shape[0] != y.shape[0]:
#       3         return (-1)
#       4     N = x.shape[1]
#       5     distance=[0]*N
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
# Conclusoes: nao consegue reconhecer quando tem uma luz de lado. Caso contrario, faz bem o reconhecimento.
