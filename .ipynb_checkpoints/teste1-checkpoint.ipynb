# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
run TP1920.py

# %%
# Converter e definir as imagens
#resizeImageAndConvert()

# %%
# Ler das imagens para uma matriz 'X' e um array 'lista'
X, lista, size = readImages()
size
# Out:
# 62

# %%
X[1].shape
# Out:
# (65025,)

# %%
X.shape
# Out:
# (47, 65025)

# %%
# Obter os vectores pp de acordo com um certo nivel de confianca
eigenvalues, eigenvectors, phi, mean, variance = pca(X, 7, 0.8)
eigenvalues
# Out:
# Número de vectores pp a usar: 9
# Número de vectores fixos a utilizar: 7
# array([1.01994464e+09, 4.78141415e+08, 3.36053510e+08, 2.66616904e+08,
#        1.91546490e+08, 1.22191317e+08, 8.59163809e+07, 8.12207088e+07,
#        6.74506172e+07, 6.16549531e+07, 5.37936223e+07, 4.70342630e+07,
#        4.17133385e+07, 3.49278146e+07, 3.29391186e+07, 2.92501206e+07,
#        2.66933235e+07, 2.35356245e+07, 2.23119401e+07, 1.95326285e+07,
#        1.86198405e+07, 1.82357276e+07, 1.71833147e+07, 1.65108040e+07,
#        1.54174881e+07, 1.48835256e+07, 1.42149019e+07, 1.20865232e+07,
#        1.15967037e+07, 1.12013461e+07, 1.06331373e+07, 9.85171997e+06,
#        9.39494878e+06, 9.21297889e+06, 8.62613652e+06, 8.17078621e+06,
#        7.68327913e+06, 7.06208274e+06, 6.80374874e+06, 6.54942325e+06,
#        5.78899518e+06, 4.64922135e+06, 4.39833350e+06, 4.15166260e+06,
#        4.07303838e+06, 3.75938978e+06, 1.27892799e-22])

# %%
# Obter os vectores pp de acordo com um certo nivel de confianca
eigenvalues, eigenvectors, phi, mean, variance = pca(X, 7, 0.8)
# Alterar nome da variável
ponto=eigenvalues
# Obter o gráfico do cotovelo
plt.figure(figsize=(10,10))
t = np.arange(0, size, 1)
plt.plot(t, eigenvalues, 'x')
#plt.plot(np.argmin(ponto), eigenvalues[np.argmin(ponto)], 'o')
plt.plot(7, eigenvalues[7], 'o')
plt.show()
# Out:
# Número de vectores pp a usar: 9
# Número de vectores fixos a utilizar: 7

# %%
eigenvectors.T[0]
# Out:
# array([-0.00020549, -0.00030448, -0.00026404, ...,  0.00281699,
#         0.00228365,  0.00175119])

# %%
# Exemplo de uma eigenface do dataset
display(plt.matshow(np.reshape(eigenvectors.T[0], (255,255)), cmap=plt.cm.RdYlGn))

# %%
# Exemplo da "cara média" do dataset
display(plt.matshow(np.reshape(mean, (255,255)), cmap='gray'))

# %%
# Obter os coeficientes das projeccoes das eigenfaces
coef_proj = coefProj(phi, eigenvectors, X.shape[0])
coef_proj
# Out:
# [array([ 2767.55250613,  3735.66750079,  -654.2132072 , -3842.5493413 ,
#          1333.95148593,   165.4347212 ,  -704.70679701]),
#  array([ 7542.17172101,   763.62825697,  -735.93332022,  4095.10554753,
#          -121.14506144,  1477.8768714 , -1079.29570103]),
#  array([-2176.79860591,  1412.23067963,  5530.73192405,   176.07292266,
#         -1267.56404155,  -340.98461911,  1219.65156843]),
#  array([-7267.09115947,   807.35288475,  1231.0653124 ,  2800.99685598,
#          2249.28950842,   370.58678199, -1541.39705621]),
#  array([-2234.60051091,  2462.17059431,  5061.63578844,   614.24281885,
#         -1704.14430396,   -33.24169164,  1111.87158347]),
#  array([  467.23475898, -4712.30233948,   908.76999857,   328.92119035,
#         -2342.45138498, -2071.44269616, -2907.43306978]),
#  array([-5640.88900378,  -405.80091611, -2639.69144365,  -392.81693628,
#          -986.47867012,   929.95438352,   462.87671256]),
#  array([-7640.6348064 ,  -849.03234883, -3580.37056614,  2267.34513299,
#          2956.85094438, -1176.99662505,  -107.98961471]),
#  array([ 3214.149681  , -7569.36322981,   798.97299211, -2608.85715444,
#          2351.47265542,   956.67497796,  3144.85177875]),
#  array([ 6104.09368299,  1351.47331128,  -779.00782673,  2376.66822583,
#            52.65894902, -1368.66347643,  1813.49047236]),
#  array([-6171.65494773, -1637.3187862 , -3380.50139951,   909.20487114,
#          4680.08839186, -2260.61235159,  -115.43674484]),
#  array([-2246.45030821,   549.37309319, -2847.88655197,  -463.64690109,
#         -5956.72056621,  1263.30895955,   279.23685914]),
#  array([ 3759.13922407, -7658.27204093,  -269.83830141, -2025.31842678,
#          1123.70171214,  1451.95458717,  1519.17951015]),
#  array([-7341.68720848,  -248.84310896, -3598.1499853 ,  1405.37830118,
#           383.28413419,   499.77145566,   -62.25471027]),
#  array([-3856.20588794,   128.87614054, -3338.2674339 , -1236.36162937,
#         -4759.19138773,   930.99625416,  1018.28022229]),
#  array([-4232.04427192,   625.0331101 ,  3979.37030183,  -137.7778194 ,
#          1550.7103269 ,  -294.06271991,   843.39089677]),
#  array([-2283.38270504,  2365.33461999,  3438.38090703,  -262.01652693,
#         -1859.87525897,  1313.2208821 ,   486.47286638]),
#  array([-6490.24316502,  -569.75203062, -4064.34663431,   599.29282596,
#          -861.96414201,   640.00496212,   274.0487559 ]),
#  array([ 2815.93422361,  3618.10214737,  -302.56263333, -3550.23481103,
#           781.41088316,   212.80737438,  -456.72835129]),
#  array([-5100.24405422,   531.09445757, -3236.797296  , -1022.83685457,
#         -3112.33646629,  1755.69922866,   785.6073731 ]),
#  array([-6966.75523582,   136.63608391, -4353.69653123,   471.86997021,
#         -1119.59882565,   936.02659939,   535.97255585])]

# %%
# Imagem para teste
input_img = Image.open('TestSet/DSC_0100.gif').convert('L')
input_img
# Out:
# <PIL.Image.Image image mode=L size=255x255 at 0x125F9E8D0>

# %%
# Teste do reconhecimento
dist, test_coef_proj = testar(input_img, mean, eigenvectors, eigenvalues, X.shape[0], coef_proj, 'mahalanobis')
image = 0
if np.size(dist) > 0 : 
    image = lista[np.argmin(dist)]
image
# Out:
# Imagem nr.: 45
# Distancia minima: 0.0042
# Distancia máxima: 0.6931
# <PIL.Image.Image image mode=L size=255x255 at 0x128125590>

# %%
coef_proj = np.reshape(coef_proj, (eigenvectors.shape[1], size))
#distance = np.sum( np.divide((coef_proj[:,4]-test_coef_proj)**2, eigenvalues[:eigenvectors.shape[1]]) )
#distance

# %%
def mahalanobis(x, y, eigenvalues, k):
    if x.shape[0] != y.shape[0]:
        return (-1)
    N = x.shape[1]
    distance=[0]*N
    for i in range(N):
        distance[i] = [np.sum(np.divide((x[:,i]-y)**2, eigenvalues[:k]))]
    return distance

# %%
coef_proj = np.reshape(coef_proj, (eigenvectors.shape[1], size))
dist = mahalanobis(coef_proj, test_coef_proj, eigenvalues, eigenvectors.shape[1])
distanceMahalanobis = np.sum(dist)
distanceMahalanobis
# Out:
# 200.80419063685375

# %%
# Conclusoes: nao consegue reconhecer quando tem uma luz de lado. Caso contrario, faz bem o reconhecimento.
