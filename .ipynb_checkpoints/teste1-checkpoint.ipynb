# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
run TP1920.py

# %%
# Converter e definir as imagens
#resizeImageAndConvert()

# %%
# Ler das imagens para uma matriz 'X' e um array 'lista'
X, lista, size = readImages()
size
# Out:
# 50

# %%
X[1].shape
# Out:
# (65025,)

# %%
X.shape
# Out:
# (50, 65025)

# %%
# Obter os vectores pp de acordo com um certo nivel de confianca
eigenvalues, eigenvectors, phi, mean, variance = pca(X, 7, 0.8)
eigenvalues
# Out:
# Número de vectores pp a usar: 10
# Número de vectores fixos a utilizar: 7
# array([1.04805502e+09, 5.08330144e+08, 3.44590661e+08, 2.85447755e+08,
#        2.13210753e+08, 1.26246962e+08, 9.90757072e+07, 8.50869176e+07,
#        6.78433980e+07, 6.33248144e+07, 5.99760152e+07, 5.08283994e+07,
#        3.92393896e+07, 3.42029243e+07, 3.33963933e+07, 3.21148100e+07,
#        2.71393815e+07, 2.62371511e+07, 2.44897500e+07, 2.11425705e+07,
#        2.02773323e+07, 1.90177469e+07, 1.84632514e+07, 1.79293746e+07,
#        1.68332153e+07, 1.57589757e+07, 1.43176675e+07, 1.36869090e+07,
#        1.32022698e+07, 1.24082432e+07, 1.13268892e+07, 1.11266419e+07,
#        1.07259374e+07, 9.88760259e+06, 9.79018740e+06, 9.02547675e+06,
#        8.78546369e+06, 8.19991359e+06, 8.07164022e+06, 7.15880179e+06,
#        6.91452849e+06, 6.63485130e+06, 5.69480827e+06, 5.43647417e+06,
#        4.28214799e+06, 4.21182531e+06, 4.01567147e+06, 3.87016592e+06,
#        3.67742397e+06, 1.44603418e-22])

# %%
# Obter os vectores pp de acordo com um certo nivel de confianca
eigenvalues, eigenvectors, phi, mean, variance = pca(X, 7, 0.8)
# Alterar nome da variável
ponto=eigenvalues
# Obter o gráfico do cotovelo
plt.figure(figsize=(10,10))
t = np.arange(0, size, 1)
plt.plot(t, eigenvalues, 'x')
#plt.plot(np.argmin(ponto), eigenvalues[np.argmin(ponto)], 'o')
plt.plot(7, eigenvalues[7], 'o')
plt.show()
# Out:
# Número de vectores pp a usar: 10
# Número de vectores fixos a utilizar: 7

# %%
eigenvectors.T[0]
# Out:
# array([ 6.77240508e-05,  7.95830075e-06,  4.48935540e-05, ...,
#        -1.92294935e-03, -2.00071174e-03, -1.89139744e-03])

# %%
# Exemplo de uma eigenface do dataset
display(plt.matshow(np.reshape(eigenvectors.T[0], (255,255)), cmap=plt.cm.RdYlGn))

# %%
# Exemplo da "cara média" do dataset
display(plt.matshow(np.reshape(mean, (255,255)), cmap='gray'))

# %%
# Obter os coeficientes das projeccoes das eigenfaces
coef_proj = coefProj(phi, eigenvectors, X.shape[0])
coef_proj
# Out:
# [array([-2430.32330271,  3666.8486166 ,   -31.47442465, -4116.64454117,
#           888.39763221,  -290.32029262,   486.09282884]),
#  array([-7201.12036027,   986.26000178, -1074.49350365,  3826.78365208,
#           216.20873155, -2081.91640557,   688.1760247 ]),
#  array([ 2187.3637065 ,  1122.57660082,  5870.97611227,   761.09105847,
#          -481.65919918,   545.72031838, -1403.04737125]),
#  array([ 7298.09469884,   712.86160655,  1831.12249628,  2496.54089324,
#          2960.35451577, -1159.9986622 ,   -42.73339344]),
#  array([ 2344.34089954,  2180.51806812,  5495.1233481 ,  1185.88536434,
#          -908.99488661,   263.02147841, -1693.56943717]),
#  array([  -67.99371908, -4620.69668976,  1032.33586586,   844.76290218,
#         -1843.23548219,  1601.69587083,  2990.78681487]),
#  array([ 7945.78370581,  -671.99852474, -2923.81242032,  1634.69433964,
#          3731.92572445,  -129.88255637,  1417.39505397]),
#  array([-3005.68638623, -7517.9362896 ,   300.25590977, -2563.4258814 ,
#          1913.62409112,   576.04751205, -2947.30678057]),
#  array([-5755.23059416,  1638.97988351, -1170.64628429,  2382.70513566,
#           535.86455694,  1664.66277645,  -755.09349358]),
#  array([ 6501.81805234, -1415.09286287, -2834.18117863,   339.1584146 ,
#          5211.47602251,   708.0164246 ,  1005.76783665]),
#  array([-5967.56961128, -5579.52281669,   300.72091788, -1533.46842358,
#         -1166.08717553, -3295.00446794,  1406.51080456]),
#  array([ 5688.67686123,   533.66788136, -4113.3892608 ,    70.16182501,
#         -4330.20876698,    54.46511627, -1720.49347468]),
#  array([ 2999.46076228,   792.20251579, -2213.4309504 ,   219.56181968,
#         -5837.29993908,  -442.60908413, -1111.48788283]),
#  array([-3469.75750202, -7586.29895556,  -744.62678126, -2034.61561095,
#           675.64434568,  -253.63062407, -1821.58240595]),
#  array([ 7696.39732072,  -129.9824802 , -2721.50902778,   949.1914816 ,
#          1013.2501642 , -1247.35743817,  1189.97510855]),
#  array([-1854.55790548,   974.24348959, -4120.27162907,  1563.26635052,
#           718.28347614,  2828.85802059, -2400.70102852]),
#  array([-1719.25262005,  3217.65144144,   492.85493191, -3505.81619771,
#          1041.34505676,  -730.65203807,   456.94477432]),
#  array([ 4614.17447894,   406.55306617, -2742.62705906,  -651.77241235,
#         -4656.36243472,    23.05674533, -1808.78660504]),
#  array([ 2400.49260315,  2082.42796571,  4026.46235342,   236.94438643,
#         -1672.35857178,  -783.26382119,  -750.22870932]),
#  array([ 6936.47097347,  -409.42673729, -3278.17217367,   303.20174036,
#          -348.43661854,  -820.87959019,   836.42568519]),
#  array([-2476.11284664,  3579.84406863,   303.23556881, -3748.36490702,
#           420.74332347,  -290.41829248,   313.51844359]),
#  array([ 5670.40868795,   611.91296327, -2383.74357996,  -921.24006917,
#         -2839.29034346, -1373.52064078,  -378.97280064]),
#  array([ 7461.88295122,   292.68677666, -3495.8431114 ,   210.57906894,
#          -657.63490573, -1084.9976511 ,   447.92625102])]

# %%
# Imagem para teste
input_img = Image.open('TestSet/DSC_0100.gif').convert('L')
input_img
# Out:
# <PIL.Image.Image image mode=L size=255x255 at 0x12656D310>

# %%
# Teste do reconhecimento
dist, test_coef_proj = testar(input_img, mean, eigenvectors, eigenvalues, X.shape[0], coef_proj, 'mahalanobis')
image = 0
if np.size(dist) > 0 : 
    image = lista[np.argmin(dist)]
image
# Out:
# Falhou no reconhecimento.
# 0

# %%
coef_proj = np.reshape(coef_proj, (eigenvectors.shape[1], size))
#distance = np.sum( np.divide((coef_proj[:,4]-test_coef_proj)**2, eigenvalues[:eigenvectors.shape[1]]) )
#distance

# %%
def mahalanobis(x, y, eigenvalues, k):
    if x.shape[0] != y.shape[0]:
        return (-1)
    N = x.shape[1]
    distance=[0]*N
    for i in range(N):
        distance[i] = [np.sum(np.divide((x[:,i]-y)**2, eigenvalues[:k]))]
    return distance

# %%
coef_proj = np.reshape(coef_proj, (eigenvectors.shape[1], size))
dist = mahalanobis(coef_proj, test_coef_proj, eigenvalues, eigenvectors.shape[1])
distanceMahalanobis = np.sum(dist)
distanceMahalanobis
# Out:
# 200.80419063685375

# %%
# Conclusoes: nao consegue reconhecer quando tem uma luz de lado. Caso contrario, faz bem o reconhecimento.
