# %%
run yales.py

# %%
# Ler das imagens para uma matriz 'X' e um array 'lista'
X, lista, size = readImages()
size
# Out:
# 135

# %%
X[1].shape
# Out:
# (77760,)

# %%
X.shape
# Out:
# (135, 77760)

# %%
# Obter os vectores pp de acordo com um certo nivel de confianca
k, eigenvalues, eigenvectors, phi, mean, variance = pca(X, 5, 1)
eigenvalues
# Out:
# 128
# array([1.44318218e+10, 6.30507308e+09, 4.06782865e+09, 3.47216907e+09,
#        2.23185576e+09, 1.89082289e+09, 1.28543535e+09, 1.07324364e+09,
#        1.02948911e+09, 9.03158968e+08, 6.46046535e+08, 5.73357275e+08,
#        4.60385827e+08, 4.40211152e+08, 4.05823634e+08, 3.79246134e+08,
#        3.35584544e+08, 3.17700453e+08, 2.86464120e+08, 2.53509339e+08,
#        2.35506556e+08, 2.07349407e+08, 2.00257206e+08, 1.89083688e+08,
#        1.67521371e+08, 1.65100496e+08, 1.55711344e+08, 1.45879747e+08,
#        1.37841624e+08, 1.29038239e+08, 1.26826592e+08, 1.15695695e+08,
#        1.13407457e+08, 1.08853433e+08, 1.04994188e+08, 9.80713102e+07,
#        9.13636289e+07, 8.97968729e+07, 8.64722725e+07, 8.37519768e+07,
#        7.87545185e+07, 7.70216671e+07, 7.52194570e+07, 7.16397224e+07,
#        6.88205227e+07, 6.77572560e+07, 6.50444913e+07, 6.19825480e+07,
#        5.81075712e+07, 5.76287073e+07, 5.60557711e+07, 5.52910808e+07,
#        5.40671832e+07, 5.35155739e+07, 5.11875236e+07, 4.88871887e+07,
#        4.75371738e+07, 4.58339851e+07, 4.53788641e+07, 4.49905775e+07,
#        4.38825054e+07, 4.26456550e+07, 4.11034880e+07, 4.04395096e+07,
#        3.89334476e+07, 3.83323747e+07, 3.70933997e+07, 3.57715929e+07,
#        3.51709038e+07, 3.48686396e+07, 3.39593037e+07, 3.33228894e+07,
#        3.25898016e+07, 3.15100812e+07, 3.11754389e+07, 3.05386476e+07,
#        2.90114708e+07, 2.86115722e+07, 2.76775985e+07, 2.75636936e+07,
#        2.71426745e+07, 2.70130095e+07, 2.61898382e+07, 2.50915946e+07,
#        2.47546036e+07, 2.36868909e+07, 2.32300920e+07, 2.25479370e+07,
#        2.17782650e+07, 2.16004599e+07, 2.09683073e+07, 1.99098444e+07,
#        1.95253316e+07, 1.91679114e+07, 1.86127804e+07, 1.83961482e+07,
#        1.78133828e+07, 1.74941434e+07, 1.70851284e+07, 1.64038236e+07,
#        1.59331467e+07, 1.56287241e+07, 1.47276104e+07, 1.38735123e+07,
#        1.33899210e+07, 1.28395722e+07, 1.27999689e+07, 1.26117466e+07,
#        1.20437425e+07, 1.20172749e+07, 1.11553763e+07, 1.06258920e+07,
#        1.05453336e+07, 1.00384463e+07, 9.71309019e+06, 9.22012847e+06,
#        8.77736496e+06, 8.01131044e+06, 7.76766480e+06, 6.86209272e+06,
#        6.36981735e+06, 5.94404129e+06, 5.78932865e+06, 5.48824285e+06,
#        4.98693363e+06, 4.33274474e+06, 1.62700578e+06, 1.29637617e+06,
#        6.20698121e-22, 8.08044731e-23, 5.37752246e-23, 5.37752246e-23,
#        5.37752246e-23, 5.37752246e-23, 5.37752246e-23])

# %%
#plt.figure(figsize=(10,10))
#t = np.arange(0, size, 1)
#plt.plot(t, eigenvalues, 'x')
#plt.plot(5, eigenvalues[5], 'o')
#plt.show()

# %%
eigenvectors.T[0]
# Out:
# array([-0.00059673, -0.0005939 , -0.00058761, ...,  0.00347165,
#         0.00335092,  0.00317014])

# %%
# Exemplo de uma eigenface do dataset
display(plt.matshow(np.reshape(eigenvectors.T[0], (255,255)), cmap='gray'))

# %%
# Exemplo da "cara média" do dataset
display(plt.matshow(np.reshape(mean, (255,255)), cmap='gray'))

# %%
# Obter os coeficientes das projeccoes das eigenfaces
coef_proj = coefProj(phi, eigenvectors, X.shape[0])
coef_proj
# Out:
# array([[-8.98046194e+03,  6.68892047e+02,  3.35818559e+03,
#          2.79870678e+03, -2.07730862e+03, -9.74680549e+03,
#          6.12615166e+02,  3.72754495e+03,  2.64357299e+03,
#         -1.12207780e+03, -9.65501973e+03,  9.34225325e+02,
#          4.05778242e+03,  2.64916632e+03, -1.50870873e+03,
#          9.70307655e+03,  3.23933616e+03,  3.38998001e+03],
#        [-1.79929064e+03,  9.56917439e+02,  8.84187789e+03,
#          2.94392690e+03,  3.78207885e+03, -1.23482282e+03,
#          2.24451200e+03,  9.16498393e+03,  3.07133301e+03,
#          3.82329142e+03, -1.37761383e+03,  1.99666346e+03,
#          5.65822775e+03, -3.99130476e+03, -1.97859274e+03,
#          3.11849824e+03,  1.53978592e+03,  4.47048271e+03],
#        [-3.47355154e+03, -1.57375477e+03,  2.96722284e+03,
#          1.91123935e+03,  5.41880170e+03, -4.26755937e+03,
#         -1.33542381e+03,  3.86386979e+03,  2.32794616e+03,
#         -2.34983042e+03,  5.20186282e+03, -3.89337189e+03,
#          4.45626909e+02, -1.81077638e+02, -3.57873918e+03,
#          4.34629890e+03, -5.39502159e+03, -1.44295760e+02],
#        [ 8.42135163e+00, -3.83264517e+03,  4.53097504e+03,
#         -5.32847408e+03,  2.21938588e+02,  5.27096137e+02,
#          7.72919540e+03, -1.87502534e+03, -1.67580920e+03,
#         -9.22500880e+02, -3.90667767e+03,  7.12867189e+03,
#         -1.71903234e+03, -2.92782245e+02, -1.37839712e+03,
#         -3.36902416e+03,  7.52129903e+03, -1.48468728e+03],
#        [-5.92784718e+02, -1.46287724e+03, -3.58489694e+03,
#         -9.21340854e+03, -2.99848659e+01,  2.78924422e+02,
#         -1.72332071e+03,  2.16634723e+03, -8.92852533e+03,
#         -4.79639125e+03, -8.02273587e+02, -4.58275483e+03,
#          1.57193589e+03, -9.35118107e+03, -3.91192861e+03,
#          4.50500968e+02, -4.08272862e+03,  4.98906617e+02]])

# %%
# Imagem para teste
input_img = Image.open('tiago_wink.gif').convert('L')
input_img
# Out:
# <PIL.Image.Image image mode=L size=255x255 at 0x5DC090>

# %%
# Teste do reconhecimento
test_coef_proj = testar(input_img, mean, eigenvectors, eigenvalues, 39000, X.shape[0], coef_proj)
testar(input_img, mean, eigenvectors, eigenvalues, limit, size, coef_proj, distance ="mahalanobis"):
# Out:
# [2.71148549e+08 2.90270285e+04 9.35414541e+06 1.16979491e+06
#  5.04511658e+06]
# [46474691.6310166   8564877.99684619  1342488.2863392   7614817.90594412
#   1893489.30809806]
# [1.70398998e+07 1.16889435e+08 1.14400861e+07 3.14062088e+07
#  5.56483955e+05]
# [21971907.77481498 24143373.94166616  5411839.88706041 18107789.59811626
#  40634124.30489211]
# [91459299.8461148  33082544.01584287 34034371.76312087  1677252.43967518
#   7890107.6788988 ]
# [2.96973960e+08 5.39991324e+05 1.48414679e+07 2.56078521e+06
#  9.72094395e+06]
# [47245164.15170816 17759277.9885646    847001.80878388 77481270.81607793
#   1244558.24475838]
# [1.41269386e+07 1.23980381e+08 1.83095551e+07 6.43005301e+05
#  2.50526842e+07]
# [23450328.75572793 25411649.22774475  7524284.7074067    363199.04795874
#  37083312.40813388]
# [7.41011889e+07 3.35583306e+07 3.74319417e+06 2.26949233e+04
#  3.83169992e+06]
# [2.93818909e+08 3.50523212e+05 3.15502354e+07 8.02888348e+06
#  4.14792215e+06]
# [42927414.80707473 15731752.27779764 12098397.61616215 67269869.63886786
#   3040965.44508206]
# [11753546.17867384 58184730.18357356   740845.30445456   417164.99760694
#  19455635.66036414]
# [23396188.10554366  4087031.98853366    54764.96844582   608972.6203799
#  42409564.85525122]
# [8.09070688e+07 7.97252843e+01 1.00086331e+07 9.31762756e+04
#  1.15135088e+06]
# [ 4914865.57325107 25889393.38710713 22670889.00730203  5271041.70344624
#  10820279.87033129]
# [18035231.99593338 12316237.63956936 24799650.85845979 73864540.84153578
#   1547063.83707384]
# [16778419.66678734 41475487.67158026    73333.20393003   169363.5734328
#  11141075.94195244]
# Falhou no reconhecimento.
# Imagem nr.: 15
# Distancia minima: 1.5303746197671306e+16

# %%
# Imagema que se assemelha no dataset
lista[15]
# Out:
# <PIL.Image.Image image mode=L size=255x255 at 0x5C7430>

# %%
coef_proj=np.reshape(coef_proj, (5,19))
distance = np.sum(np.divide((coef_proj[:,4]-test_coef_proj)**2, eigenvalues[:5]))
distance
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-314-b6e906244b72> in <module>
# ----> 1 coef_proj=np.reshape(coef_proj, (5,19))
#       2 distance = np.sum(np.divide((coef_proj[:,4]-test_coef_proj)**2, eigenvalues[:5]))
#       3 distance
#
# c:\users\lera\appdata\local\programs\python\python37-32\lib\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     277            [5, 6]])
#     278     """
# --> 279     return _wrapfunc(a, 'reshape', newshape, order=order)
#     280
#     281
#
# c:\users\lera\appdata\local\programs\python\python37-32\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      49 def _wrapfunc(obj, method, *args, **kwds):
#      50     try:
# ---> 51         return getattr(obj, method)(*args, **kwds)
#      52
#      53     # An AttributeError occurs if the object does not have
#
# ValueError: cannot reshape array of size 90 into shape (5,19)

# %%
def mahalanobis(x, y, eigenvalues, k):
    if x.shape[0] != y.shape[0]:
        return (-1)
    N = x.shape[1]
    distance=[0]*N
    for i in range(N):
        distance[i] = [np.sum(np.divide((x[:,i]-y)**2, eigenvalues[:k]))]
    return distance

# %%
coef_proj = np.reshape(coef_proj, (eigenvectors.shape[1], size))
dist=[]
mahalanobis(coef_proj, test_coef_proj, eigenvalues, eigenvectors.shape[1])
# Out:
# [[1.2205762737094963],
#  [1.0470248681931018],
#  [0.8188953672865905],
#  [0.6636286620438331],
#  [1.197628977075607],
#  [0.8820711788009045],
#  [0.8246338707330036],
#  [1.0956689840462457],
#  [1.701767529376395],
#  [0.7774818793651067],
#  [1.2878956939180646],
#  [1.0796533882260808],
#  [0.6577974360710234],
#  [1.7107367420721549],
#  [0.9692304754120853],
#  [0.15002705975156444],
#  [0.45678533859084036],
#  [0.5607612278508963],
#  [0.6875326134831423]]

# %%
# Conclusoes: nao consegue reconhecer quando tem uma luz de lado. Caso contrario, faz bem o reconhecimento.
